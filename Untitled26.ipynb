# %%
dict_data = {'id_port': 16,'c_x': 25,'c_y': 0.45,'height': 66,'width': 109}
dict_data
# Out:
# {'id_port': 16, 'c_x': 25, 'c_y': 0.45, 'height': 66, 'width': 109}

# %%
some = [55,33,22,11]

bytearray(some)
# Out:
# bytearray(b'7!\x16\x0b')

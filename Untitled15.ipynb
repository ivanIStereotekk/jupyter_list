# %%
# !pip install pyttsx3
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# /usr/local/lib/python3.10/site-packages/pyttsx3/drivers/nsss.py:12: ObjCSuperWarning: Objective-C subclass uses super(), but super is not objc.super
#   class NSSpeechDriver(NSObject):
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/pyttsx3/__init__.py:20, in init(driverName, debug)
#      19 try:
# ---> 20     eng = _activeEngines[driverName]
#      21 except KeyError:
#
# File /usr/local/Cellar/python@3.10/3.10.11/Frameworks/Python.framework/Versions/3.10/lib/python3.10/weakref.py:137, in WeakValueDictionary.__getitem__(self, key)
#     136     self._commit_removals()
# --> 137 o = self.data[key]()
#     138 if o is None:
#
# KeyError: None
#
# ...

# %%
import pyttsx3
engine = pyttsx3.init()
engine.say("I will speak this text")
engine.runAndWait()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/pyttsx3/__init__.py:20, in init(driverName, debug)
#      19 try:
# ---> 20     eng = _activeEngines[driverName]
#      21 except KeyError:
#
# File /usr/local/Cellar/python@3.10/3.10.11/Frameworks/Python.framework/Versions/3.10/lib/python3.10/weakref.py:137, in WeakValueDictionary.__getitem__(self, key)
#     136     self._commit_removals()
# --> 137 o = self.data[key]()
#     138 if o is None:
#
# KeyError: None
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pyttsx3
# ----> 2 engine = pyttsx3.init()
#       3 engine.say("I will speak this text")
#       4 engine.runAndWait()
#
# ...

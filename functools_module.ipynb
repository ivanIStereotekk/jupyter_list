# %%
# F U N C T O O L S
from functools import reduce, partial


def check(a,b):
    return a > b

ss = partial(check,a=10,b=10)
ss()
# Out:
# False

# %%
from functools import partialmethod


class Demo:
	def __init__(self):
		self.color = 'black'

	def _color(self, type):
		self.color = type

        
        
set_red = partialmethod(_color, type='red')
set_blue = partialmethod(_color, type='blue')
set_green = partialmethod(_color, type='green')


obj = Demo()
print(obj.color)
obj.set_green()
print(obj.color)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 13
#       8 	def _color(self, type):
#       9 		self.color = type
# ---> 13 set_red = partialmethod(_color, type='red')
#      14 set_blue = partialmethod(_color, type='blue')
#      15 set_green = partialmethod(_color, type='green')
#
# NameError: name '_color' is not defined

# %%
# A B C collection pattern
import string

abc = list(string.ascii_lowercase)
len(abc)
# Out:
# 26

# %%
class C:
    def __init__(self):
        self._x = None

    def getx(self):
        return self._x

    def setx(self, value):
        self._x = value

    def delx(self):
        del self._x

    x = property(getx, setx, delx, "I'm the 'x' property.")
    
    print(x.__repr__)
    
    
cl = C()
cl.x = 100
cl.__dict__

# del cl.x

cl.__dict__
# Out:
# <method-wrapper '__repr__' of property object at 0x105fd8900>
# {'_x': 100}

# %%
class One:
    one = 'helllo im hashed obj'
    sec = [1,2,3,4,4,5]
    def abc(one):
        return f"{one} some additional string"

    
on = One()    
    
dit = {on:"hello"} 

dit
# Out:
# {<__main__.One at 0x112af0ee0>: 'hello'}

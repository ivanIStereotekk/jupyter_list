# %%
# !pip install redis
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.3/240.3 kB 1.5 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
# DECORATORS

def connect_database(port,url):
    def conf(insider_function):
        def wrapper(*args,**kwargs):
            return f" OUTER:{insider_function(*args,**kwargs) ,port,url}"
        return wrapper
    return conf


@connect_database(port=8080,url='localhost')
def inner(a,b):
    return f" INNER FUNC {a,b}"

#inner = decorator(inner) - Using decorator the same effect as this defining
    
inner(5,2)
# Out:
# " OUTER:(' INNER FUNC (5, 2)', 8080, 'localhost')"

# %%
# import redis
# #host='localhost', port=6379, decode_responses=True)
 
# def connect_redis(host,port,decode_responses):
#     connection = redis.Redis(host, port, decode_responses)
#     def passed_func(inside_func):
#         def wrapp(*args,**kwargs):
#             return inside_func(*args,**kwargs)
#         return wrapp
#     conn = connection
#     return passed_func,conn

# @connect_redis(host='localhost',port=6379,decode_responses=True)
# def set_data(data,value):
#     return conn.set(data,value)



# print(set_data('username','VanyaGoncharov'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[203], line 14
#      10     conn = connection
#      11     return passed_func,conn
#      13 @connect_redis(host='localhost',port=6379,decode_responses=True)
# ---> 14 def set_data(data,value):
#      15     return conn.set(data,value)
#      19 print(set_data('username','VanyaGoncharov'))
#
# TypeError: 'tuple' object is not callable

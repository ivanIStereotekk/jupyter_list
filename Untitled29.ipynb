# %%
# !python3 -m pip install pywhatkit
# !Fix Flask import error
# Out:
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/numpy-1.26.1-py3.11.egg-info due to invalid metadata entry 'name'
# DEPRECATION: Loading egg at /usr/local/lib/python3.11/site-packages/FoxDot-0.8.12-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: pywhatkit in /usr/local/lib/python3.11/site-packages (5.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/site-packages (from pywhatkit) (10.1.0)
# Requirement already satisfied: pyautogui in /usr/local/lib/python3.11/site-packages (from pywhatkit) (0.9.54)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/site-packages (from pywhatkit) (2.31.0)
# Requirement already satisfied: wikipedia in /usr/local/lib/python3.11/site-packages (from pywhatkit) (1.4.0)
# Requirement already satisfied: Flask in /usr/local/lib/python3.11/site-packages (from pywhatkit) (3.0.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /usr/local/lib/python3.11/site-packages (from Flask->pywhatkit) (3.0.1)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/site-packages (from Flask->pywhatkit) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/site-packages (from Flask->pywhatkit) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/site-packages (from Flask->pywhatkit) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/site-packages (from Flask->pywhatkit) (1.7.0)
# Requirement already satisfied: pymsgbox in /usr/local/lib/python3.11/site-packages (from pyautogui->pywhatkit) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in /usr/local/lib/python3.11/site-packages (from pyautogui->pywhatkit) (1.0.7)
# Requirement already satisfied: pyscreeze>=0.1.21 in /usr/local/lib/python3.11/site-packages (from pyautogui->pywhatkit) (0.1.30)
# Requirement already satisfied: pygetwindow>=0.0.5 in /usr/local/lib/python3.11/site-packages (from pyautogui->pywhatkit) (0.0.9)
# Requirement already satisfied: mouseinfo in /usr/local/lib/python3.11/site-packages (from pyautogui->pywhatkit) (0.1.3)
# Requirement already satisfied: pyobjc-core in /usr/local/lib/python3.11/site-packages (from pyautogui->pywhatkit) (10.1)
# Requirement already satisfied: pyobjc-framework-quartz in /usr/local/lib/python3.11/site-packages (from pyautogui->pywhatkit) (10.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests->pywhatkit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->pywhatkit) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests->pywhatkit) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->pywhatkit) (2023.11.17)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/site-packages (from wikipedia->pywhatkit) (4.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from Jinja2>=3.1.2->Flask->pywhatkit) (2.1.3)
# Requirement already satisfied: pyrect in /usr/local/lib/python3.11/site-packages (from pygetwindow>=0.0.5->pyautogui->pywhatkit) (0.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/site-packages (from beautifulsoup4->wikipedia->pywhatkit) (2.5)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.11/site-packages (from mouseinfo->pyautogui->pywhatkit) (1.8.2)
# Requirement already satisfied: rubicon-objc in /usr/local/lib/python3.11/site-packages (from mouseinfo->pyautogui->pywhatkit) (0.4.7)
# Requirement already satisfied: pyobjc-framework-Cocoa>=10.1 in /usr/local/lib/python3.11/site-packages (from pyobjc-framework-quartz->pyautogui->pywhatkit) (10.1)
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/numpy-1.26.1-py3.11.egg-info due to invalid metadata entry 'name'
# /bin/bash: Fix: command not found

# %%
# import pywhatkit
    
    
# ascii_art = pywhatkit.image_to_ascii_art("/Users/ewan/Desktop/ivan001.jpg")
# print(ascii_art)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pywhatkit
#       4 ascii_art = pywhatkit.image_to_ascii_art("/Users/ewan/Desktop/ivan001.jpg")
#       5 print(ascii_art)
#
# ModuleNotFoundError: No module named 'pywhatkit'

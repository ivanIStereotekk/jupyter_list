// %% [markdown]
// # //      TYPE_SCRIPT LESSONS

// %%
let toUpper = (wrd) => {
    console.log(wrd.toUpperCase())   
}

toUpper("hello those who loves learnig they will get pretty succsess")
// Out:
// HELLO THOSE WHO LOVES LEARNIG THEY WILL GET PRETTY SUCCSESS

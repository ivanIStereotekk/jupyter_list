# %% [markdown]
# ##
# Count the number of Duplicates
# Write a function that will return the count of distinct case-insensitive alphabetic characters and numeric digits that occur more than once in the input string. The input string can be assumed to contain only alphabets (both uppercase and lowercase) and numeric digits.
#
# Example
# "abcde" -> 0 # no characters repeats more than once
# "aabbcde" -> 2 # 'a' and 'b'
# "aabBcde" -> 2 # 'a' occurs twice and 'b' twice (`b` and `B`)
# "indivisibility" -> 1 # 'i' occurs six times
# "Indivisibilities" -> 2 # 'i' occurs seven times and 's' occurs twice
# "aA11" -> 2 # 'a' and '1'
# "ABBA" -> 2 # 'A' and 'B' each occur twice

# %%
import collections
text = 'aabbccdd12345677--'
# text = 'abcdeaB'
def duplicate_count(text):
    result = []
    for it in collections.Counter(list(text.lower())).values():
        if it > 1:
            result.append(it)
    return len(result)

print(duplicate_count(text))
# Out:
# 6

# %% [markdown]
# # #Creating our new counter object - Интересный !

# %%
my_own = collections.Counter({'a':4,'b':5}) # Посчитает по ключу как будто значение/value умножает на Н{key} раз

my_own.elements() # <itertools.chain at 0x1033f21a0> - Вот такой вот иттератор !
list(my_own.elements())
# Out:
# ['a', 'a', 'a', 'a', 'b', 'b', 'b', 'b', 'b']

# %%
lis = list('hello_again')
enumerate(lis)
for i,y in enumerate(lis):
    print(i,y)
# Out:
# 0 h
# 1 e
# 2 l
# 3 l
# 4 o
# 5 _
# 6 a
# 7 g
# 8 a
# 9 i
# 10 n

# %%
hello_string = list('eeeeeeeeee888990')
coll_obj = collections.Counter(hello_string)
coll_obj.most_common()[-1]
# Out:
# ('0', 1)

# %%
cnt = collections.Counter(a=1,b=2,e=8)
con = collections.Counter(a=1,c=3,d=4)
ac = collections.Counter(a=1)

cnt & con # Returns only repeated
cnt | con # Returns all together concatenated but excludes repeated
# Out:
# Counter({'a': 1, 'b': 2, 'e': 8, 'c': 3, 'd': 4})

# %%
# SUBTRACT
ff = cnt.subtract(ac)
cnt
# Out:
# Counter({'a': -4, 'b': 2, 'e': 8})

# %%
new = collections.Counter({'x': 1, 'h': -2, 'q': 8})
dict(new)
# Out:
# {'x': 1, 'h': -2, 'q': 8}

# %%
dictionary = [ {"key1": "value1"}, {"k1": "v1", "k2": "v2", "k3": "v3"}, {}, {}, {"key1": "value1"}, {"key1": "value1"}, {"key2": "value2"} ]
def cleaner(dictionary):
    result = []
    for i in dictionary:
        cleaned = collections.Counter(i)
        result.append(dict(cleaned))
    return result
    
cleaner(dictionary)
# Out:
# [{'key1': 'value1'},
#  {'k1': 'v1', 'k2': 'v2', 'k3': 'v3'},
#  {},
#  {},
#  {'key1': 'value1'},
#  {'key1': 'value1'},
#  {'key2': 'value2'}]

# %%
# D E F A U L T D I C T

from collections import defaultdict

d = defaultdict(list)
d['one'].append(100)
d['two'].append(200)
d['tree'].append(300)
print(*d)
d
# Out:
# one two tree
# defaultdict(list, {'one': [100], 'two': [200], 'tree': [300]})
